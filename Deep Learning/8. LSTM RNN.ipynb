# %% [markdown]
# As we know Simple RNN was not able to solve the "Long term dependency" which leads to "vanishing gradient problem"
#
# https://colah.github.io/posts/2015-08-Understanding-LSTMs/
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### RNN vs LSTM RNN
# ![image.png](attachment:image.png)
#
# - as we know in RNN we have feedback loop which is basically for short term memory
# - in lstm, as RNN is there so we already having short term memory but here we also have long term memory which is like a ongooing straight line known as "Memory Cell" in which we can store the context which is important and remove the context at any point (conside this long term memory line as luggage belt in airport)

# %% [markdown]
# ## LSTM Architecture
# - It has 3 important gates:
#     - Forget gate
#     - Input gate and Candidate memory
#     - Output gate
#
# Understand the important Notation:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Forget Gate
# - in forget gate, we are combining/concatenate the vectors of h(t-1) and x(t) and then pass the result of concatenate to hidden layer neurons with sigmoid activation function, as we known signoid function will give output in range from 0-1 so F(t) will be containing vector of 0's and 1's
# - then the F(t) vector will go and apply point multiple operation with vector coming from memory cell
# - in forget gate, as name suggests will remove or forget some context or some part of context or keep the context same
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Input Gate and Candidate Memmory
# - the way we calculated the value of F(t) in forget gate, same way we will calculate the value of I(t)
# - for calculating candidate memory, the process is same but here instead of applying sigmoid activation function will apply tanh activation function
# - then we concatenate the outputs I(t) and C'(t) to get our final input gate result
# - then this final output of input gate and the vector coming from memory cell will perform the point add operation which will lead to add new context to memory cell and result in final C(t)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Output Gate
# - it is responsible for distinguish all the memory cell which represent the long term memory and hidden state which respresent the short term memory
# - our aim main is to reduce the loss function by updating the weights with the help of backward propogation
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Variants of LSTM RNN
# - In some research paper a different variant of LSTM RNN is present
#
# ![image.png](attachment:image.png)
#
# - 1st Variant: Peephole connection - Everything is same as in above LSTM RNN, the only difference:
#     - it is having a line of long term memory getting conctenated with input and short term memory
#     - means in forget gate, input gate will have C(t-1) along with h(t-1) and x(t) while output gate will have C(t) along with h(t-1) and x(t)
#     - this connection from memory cell o forget gate, inout gate and output gate is called as **"Peephole Connection"**
#     - Peephole Connection means that we let the gate layers look at the cell state
#     - means it will allow gates to look at the previous context present in memory cell and decide what to forget or add
#
# ![image-2.png](attachment:image-2.png)
#
# - 2nd Variant: Coupling forget and input gates
#     - Instead of separately deciding what to forget and what we should add new info, we make this decision together
#     - the main goal is to make sure that we only forget something then we have something to replace it's place or we are going to input something in that place
#     - means we only input new values to the state when we forget something old
