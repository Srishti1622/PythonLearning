# %% [markdown]
# As we know Simple RNN was not able to solve the "Long term dependency" which leads to "vanishing gradient problem"
#
# https://colah.github.io/posts/2015-08-Understanding-LSTMs/
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### RNN vs LSTM RNN
# ![image.png](attachment:image.png)
#
# - as we know in RNN we have feedback loop which is basically for short term memory
# - in lstm, as RNN is there so we already having short term memory but here we also have long term memory which is like a ongooing straight line in which we can store the context which is important and remove the context at any point (conside this long term memory line as luggage belt in airport)
