# %% [markdown]
# ## DBSCAN Clustering
# ![image.png](attachment:image.png)
#
# There are few terms which will be getting used in DBSCAN:
# - Core Points
# - Border Points
# - Outlier (Noise)
# - minPts: minimum number of data points
# - ε: radius to make a circle in the surrounding area
#
# NOTE: minPts and ε can be selected using hyperparameters tuning. The technique which is getting used in DBSCAN Clustering will also be able to do **"non-linear clustering"**

# %% [markdown]
# ### Core Points
# If from the point to ε radius, when the number of points (include that point) within the ε radius should be greater than or equal to minPts, will called that point as core point
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Border Points
# If from the point to ε radius, when the number of points within the ε radius should be less than minPts, will called that point as border point
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Outlier (Noise)
# If from the point to ε radius, when the number of points within the ε radius is 0, will called that point as noise
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### NOTE: the outlier is going to skip from the specific dataset, so DBSCAN Clustering will able to handle the noise in amazing way

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Advantages and Disadvantages
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Practical of DBSCAN

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.datasets import make_moons
X,y=make_moons(n_samples=250,noise=0.05)

# %%
plt.scatter(X[:,0],X[:,1],c=y)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_scaler=scaler.fit_transform(X)

# %%
from sklearn.cluster import DBSCAN

dbscan=DBSCAN(eps=0.3)
dbscan.fit(X_scaler)
# Out:
# DBSCAN(eps=0.3)

# %%
plt.scatter(X[:,0],X[:,1],c=dbscan.labels_)
